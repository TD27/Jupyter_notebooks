# %% [markdown]
# # Smartphone FLIP

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
googleSheetId='1StPX_hRan4dOpH_hBqTBxcJg3Sa9OMlaDoslYnmz5Po'
worksheetName='Dataset_3'
path='https://docs.google.com/spreadsheets/d/{0}/gviz/tq?tqx=out:csv&sheet={1}'.format(
    googleSheetId,
    worksheetName
)
dataset_3 = pd.read_csv(path)

# %% [markdown]
# ### Dataset 3

# %%
graphdata=dataset_3.iloc[1:13000,:]
dataset_3.plot(subplots=True, figsize=(15,5));
